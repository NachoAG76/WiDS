# %% [markdown]
# ## Simple Baseline script
# * Uses CatBoost (Has built in embedding support for categoricals, such as the string columns)
# * Not compared with OneHot encoding handling of string/categorical columns yet, or xgboost, lightgbm (the later can also handle categoricals natively).
#
#     *Good luck!
#
# * Target: *is_female*

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))
# Any results you write to the current directory are saved as output.

# %%
from catboost import CatBoostClassifier
# from xgboost import XGBClassifier
import lightgbm as lgb

TARGET = "is_female"

# %% [markdown]
# #### Lots of columns!
# * Some are strings, some are boolean or of very low cardinality ( 3-7 unique values).
# * Lot's of NaNs.

# %%
df = pd.read_csv("train.csv",low_memory=False)
print(df.shape)
df.head()
# Out:
# (18255, 1235)
#    train_id  AA3  AA4  AA5  AA6     AA7  AA14  AA15   DG1  is_female  \
# 0         0    3   32  3.0  NaN  323011  3854   481  1975          1
# 1         1    2   26  NaN  8.0  268131  2441   344  1981          1
# 2         2    1   16  NaN  7.0  167581   754   143  1995          1
# 3         3    4   44  5.0  NaN  445071  5705   604  1980          1
# 4         4    4   43  NaN  6.0  436161  5645   592  1958          1
#
#       ...       GN1  GN1_OTHERS GN2  GN2_OTHERS  GN3  GN3_OTHERS  GN4  \
# 0     ...      99.0         NaN  99         NaN   99         NaN   99
# 1     ...       NaN         NaN   1         NaN    2         NaN    2
# 2     ...       1.0         NaN   2         NaN    2         NaN    2
# 3     ...       NaN         NaN   2         NaN    2         NaN   99
# 4     ...       NaN         NaN   1         NaN    1         NaN    1
#
#    GN4_OTHERS  GN5  GN5_OTHERS
# 0         NaN   99         NaN
# 1         NaN    2         NaN
# 2         NaN    2         NaN
# 3         NaN   99         NaN
# 4         NaN    1         NaN
#
# [5 rows x 1235 columns]

# %% [markdown]
# ### Note: Test, Train have different ID columns!
# * ordering reset to 0 for each.
# * Best to drop unless a useful leak is identified (But then more annoying to output test set predictions, if train has different # columns).
#     * Ignore for now

# %%
test = pd.read_csv("test.csv",low_memory=False)
print(test.shape)
# Out:
# (27285, 1234)

# %% [markdown]
# #### Lots of columns which look to be based on survey responses/multiple choice questions.
# * in this case, Nulls may be the result of picking a question choice, vs not being answered. Requires digging into the data to understand how it should be addressed case by case.
#     * In short: missing value imputation may be damaging!

# %%
df.isnull().sum()
# Out:
# train_id                0
# AA3                     0
# AA4                     0
# AA5                 12602
# AA6                  5653
# AA7                     0
# AA14                    0
# AA15                    0
# DG1                     0
# is_female               0
# DG3                     0
# DG3A                    0
# DG3A_OTHERS         18205
# DG4                     0
# DG4_OTHERS          18255
# DG5_1                   0
# DG5_2                   0
# DG5_3                   0
# DG5_4                   0
# DG5_5                   0
# DG5_6                   0
# DG5_7                   0
# DG5_8                   0
# DG5_9                   0
# DG5_10                  0
# DG5_11                  0
# DG5_96                  0
# DG6                     0
# DG8a                    0
# DG8b                    0
#                     ...
# FB28_2_OTHERS       18253
# FB28_3_OTHERS       18255
# FB28_4_OTHERS       18253
# FB28_96_OTHERS      18254
# FB29_1                  0
# FB29_2                  0
# FB29_3                  0
# FB29_4                  0
# FB29_5                  0
# FB29_6                  0
# FB29_96                 0
# FB29_OTHERS         18189
# LN1A                    0
# LN1B                    0
# LN2_1                   0
# LN2_2                   0
# LN2_3                   0
# LN2_4                   0
# LN2_RIndLngBEOth     6914
# LN2_WIndLngBEOth     6911
# GN1                  4025
# GN1_OTHERS          18196
# GN2                     0
# GN2_OTHERS          18177
# GN3                     0
# GN3_OTHERS          18172
# GN4                     0
# GN4_OTHERS          18169
# GN5                     0
# GN5_OTHERS          18179
# Length: 1235, dtype: int64

# %% [markdown]
# ## Examine Non numeric columns:
# * Clear possibilities here to get less sparse features: "column is not NaN", or "sum(notNaN)(col) for col in (cols begginning with DL[0-9]"...

# %%
# https://stackoverflow.com/questions/25039626/how-do-i-find-numeric-columns-in-pandas
df.select_dtypes(exclude=[np.number])
# Out:
#       DG3A_OTHERS DG13_OTHERS DG14_OTHERS DL1_OTHERS DL2_23_OTHERS  \
# 0             NaN         NaN         NaN        NaN           NaN
# 1             NaN         NaN         NaN        NaN           NaN
# 2             NaN         NaN         NaN        NaN           NaN
# 3             NaN         NaN         NaN        NaN           NaN
# 4             NaN         NaN         NaN        NaN           NaN
# 5             NaN         NaN         NaN        NaN           NaN
# 6             NaN         NaN         NaN        NaN           NaN
# 7             NaN         NaN         NaN        NaN           NaN
# 8             NaN         NaN         NaN        NaN           NaN
# 9             NaN         NaN         NaN        NaN           NaN
# 10            NaN         NaN         NaN        NaN           NaN
# 11            NaN         NaN         NaN        NaN           NaN
# 12            NaN         NaN         NaN        NaN           NaN
# 13            NaN         NaN         NaN        NaN           NaN
# 14            NaN         NaN         NaN        NaN           NaN
# 15            NaN         NaN         NaN        NaN           NaN
# 16            NaN         NaN         NaN        NaN           NaN
# 17            NaN         NaN         NaN        NaN           NaN
# 18            NaN         NaN         NaN        NaN           NaN
# 19            NaN         NaN         NaN        NaN           NaN
# 20            NaN         NaN         NaN        NaN           NaN
# 21            NaN         NaN         NaN        NaN           NaN
# 22            NaN         NaN         NaN        NaN           NaN
# 23            NaN         NaN         NaN        NaN           NaN
# 24            NaN         NaN         NaN        NaN           NaN
# 25            NaN         NaN         NaN        NaN           NaN
# 26            NaN         NaN         NaN        NaN           NaN
# 27            NaN         NaN         NaN        NaN           NaN
# 28            NaN         NaN         NaN        NaN           NaN
# 29            NaN         NaN         NaN        NaN           NaN
# ...           ...         ...         ...        ...           ...
# 18225         NaN         NaN         NaN        NaN           NaN
# 18226         NaN         NaN         NaN        NaN           NaN
# 18227         NaN         NaN         NaN        NaN           NaN
# 18228         NaN         NaN         NaN        NaN           NaN
# 18229         NaN         NaN         NaN        NaN           NaN
# 18230         NaN         NaN         NaN        NaN           NaN
# 18231         NaN         NaN         NaN        NaN           NaN
# 18232         NaN         NaN         NaN        NaN           NaN
# 18233         NaN         NaN         NaN        NaN           NaN
# 18234         NaN         NaN         NaN        NaN           NaN
# 18235         NaN         NaN         NaN        NaN           NaN
# 18236         NaN         NaN         NaN        NaN           NaN
# 18237         NaN         NaN         NaN        NaN           NaN
# 18238         NaN         NaN         NaN        NaN           NaN
# 18239         NaN         NaN         NaN        NaN           NaN
# 18240         NaN         NaN         NaN        NaN           NaN
# 18241         NaN         NaN         NaN        NaN           NaN
# 18242         NaN         NaN         NaN        NaN           NaN
# 18243         NaN         NaN         NaN        NaN           NaN
# 18244         NaN         NaN         NaN        NaN           NaN
# 18245         NaN         NaN         NaN        NaN           NaN
# 18246         NaN         NaN         NaN        NaN           NaN
# 18247         NaN         NaN         NaN        NaN           NaN
# 18248         NaN         NaN         NaN        NaN           NaN
# 18249         NaN         NaN         NaN        NaN           NaN
# 18250         NaN         NaN         NaN        NaN           NaN
# 18251         NaN         NaN         NaN        NaN           NaN
# 18252         NaN         NaN         NaN        NaN           NaN
# 18253         NaN         NaN         NaN        NaN           NaN
# 18254         NaN         NaN         NaN        NaN           NaN
#
#       DL2_96_OTHERS DL4_OTHERS DL12_OTHERS DL28_OTHERS        G2P1_OTHERS  \
# 0               NaN        NaN         NaN         NaN                NaN
# 1               NaN        NaN         NaN         NaN                NaN
# 2               NaN        NaN         NaN         NaN  Samajvadi pension
# 3               NaN        NaN         NaN         NaN                NaN
# 4               NaN        NaN         NaN         NaN                NaN
# 5               NaN        NaN         NaN         NaN                NaN
# 6               NaN        NaN         NaN         NaN                NaN
# 7               NaN        NaN         NaN         NaN                NaN
# 8               NaN        NaN         NaN         NaN                NaN
# 9               NaN        NaN         NaN         NaN                NaN
# 10              NaN        NaN         NaN         NaN                NaN
# 11              NaN        NaN         NaN         NaN                NaN
# 12              NaN        NaN         NaN         NaN                NaN
# 13              NaN        NaN         NaN         NaN                NaN
# 14              NaN        NaN         NaN         NaN                NaN
# 15              NaN        NaN         NaN         NaN                NaN
# 16              NaN        NaN         NaN         NaN                NaN
# 17              NaN        NaN         NaN         NaN                NaN
# 18              NaN        NaN         NaN         NaN                NaN
# 19              NaN        NaN         NaN         NaN                NaN
# 20              NaN        NaN         NaN         NaN                NaN
# 21              NaN        NaN         NaN         NaN                NaN
# 22              NaN        NaN         NaN         NaN                NaN
# 23              NaN        NaN         NaN         NaN                NaN
# 24              NaN        NaN         NaN         NaN                NaN
# 25              NaN        NaN         NaN         NaN                NaN
# 26              NaN        NaN         NaN         NaN                NaN
# 27              NaN        NaN         NaN         NaN                NaN
# 28              NaN        NaN         NaN         NaN                NaN
# 29              NaN        NaN         NaN         NaN                NaN
# ...             ...        ...         ...         ...                ...
# 18225           NaN        NaN         NaN         NaN                NaN
# 18226    House wife        NaN         NaN         NaN                NaN
# 18227           NaN        NaN         NaN         NaN                NaN
# 18228           NaN        NaN         NaN         NaN                NaN
# 18229           NaN        NaN         NaN         NaN                NaN
# 18230           NaN        NaN         NaN         NaN                NaN
# 18231           NaN        NaN         NaN         NaN                NaN
# 18232           NaN        NaN         NaN         NaN                NaN
# 18233           NaN        NaN         NaN         NaN                NaN
# 18234           NaN        NaN         NaN         NaN                NaN
# 18235           NaN        NaN         NaN         NaN                NaN
# 18236           NaN        NaN         NaN         NaN                NaN
# 18237           NaN        NaN         NaN         NaN                NaN
# 18238           NaN        NaN         NaN         NaN                NaN
# 18239           NaN        NaN         NaN         NaN                NaN
# 18240           NaN        NaN         NaN         NaN                NaN
# 18241           NaN        NaN         NaN         NaN                NaN
# 18242           NaN        NaN         NaN         NaN                NaN
# 18243           NaN        NaN         NaN         NaN                NaN
# 18244           NaN        NaN         NaN         NaN                NaN
# 18245           NaN   Labourer         NaN         NaN                NaN
# 18246           NaN        NaN         NaN         NaN                NaN
# 18247           NaN        NaN         NaN         NaN                NaN
# 18248           NaN        NaN         NaN         NaN                NaN
# 18249           NaN        NaN         NaN         NaN                NaN
# 18250           NaN        NaN         NaN         NaN                NaN
# 18251           NaN        NaN         NaN         NaN                NaN
# 18252           NaN        NaN         NaN         NaN                NaN
# 18253           NaN        NaN         NaN         NaN                NaN
# 18254           NaN        NaN         NaN         NaN                NaN
#
#          ...     FB28_4_OTHERS FB28_96_OTHERS FB29_OTHERS  LN2_RIndLngBEOth  \
# 0        ...               NaN            NaN         NaN               NaN
# 1        ...               NaN            NaN         NaN           Bengali
# 2        ...               NaN            NaN         NaN             Hindi
# 3        ...               NaN            NaN         NaN             Tamil
# 4        ...               NaN            NaN         NaN         Malayalam
# 5        ...               NaN            NaN         NaN       Chattisgari
# 6        ...               NaN            NaN         NaN               NaN
# 7        ...               NaN            NaN         NaN            Telugu
# 8        ...               NaN            NaN         NaN               NaN
# 9        ...               NaN            NaN         NaN           Marathi
# 10       ...               NaN            NaN         NaN               NaN
# 11       ...               NaN            NaN         NaN             Hindi
# 12       ...               NaN            NaN         NaN               NaN
# 13       ...               NaN            NaN         NaN            Nepali
# 14       ...               NaN            NaN         NaN             Hindi
# 15       ...               NaN            NaN         NaN        Rajasthani
# 16       ...               NaN            NaN         NaN             Hindi
# 17       ...               NaN            NaN         NaN               NaN
# 18       ...               NaN            NaN         NaN   Marathi & Hindi
# 19       ...               NaN            NaN         NaN             Tamil
# 20       ...               NaN            NaN         NaN               NaN
# 21       ...               NaN            NaN         NaN             Hindi
# 22       ...               NaN            NaN         NaN               NaN
# 23       ...               NaN            NaN         NaN            Telugu
# 24       ...               NaN            NaN         NaN          Assamese
# 25       ...               NaN            NaN         NaN             Hindi
# 26       ...               NaN            NaN         NaN               NaN
# 27       ...               NaN            NaN         NaN             Hindi
# 28       ...               NaN            NaN         NaN  Telugu & Kannada
# 29       ...               NaN            NaN         NaN               NaN
# ...      ...               ...            ...         ...               ...
# 18225    ...               NaN            NaN         NaN         Malayalam
# 18226    ...               NaN            NaN         NaN             Tamil
# 18227    ...               NaN            NaN         NaN         Malayalam
# 18228    ...               NaN            NaN         NaN               NaN
# 18229    ...               NaN            NaN         NaN               NaN
# 18230    ...               NaN            NaN         NaN             Tamil
# 18231    ...               NaN            NaN         NaN             Hindi
# 18232    ...               NaN            NaN         NaN             Hindi
# 18233    ...               NaN            NaN         NaN             Hindi
# 18234    ...               NaN            NaN         NaN             Hindi
# 18235    ...               NaN            NaN         NaN               NaN
# 18236    ...               NaN            NaN         NaN           Bengali
# 18237    ...               NaN            NaN         NaN               NaN
# 18238    ...               NaN            NaN         NaN             Hindi
# 18239    ...               NaN            NaN         NaN          Gujarati
# 18240    ...               NaN            NaN         NaN           Bengali
# 18241    ...               NaN            NaN         NaN         Malayalam
# 18242    ...               NaN            NaN         NaN             Hindi
# 18243    ...               NaN            NaN         NaN          Gujarati
# 18244    ...               NaN            NaN         NaN               NaN
# 18245    ...               NaN            NaN         NaN          Gujarati
# 18246    ...               NaN            NaN         NaN           Bengali
# 18247    ...               NaN            NaN         NaN             Hindi
# 18248    ...               NaN            NaN         NaN           Bengali
# 18249    ...               NaN            NaN         NaN             Oriya
# 18250    ...               NaN            NaN         NaN               NaN
# 18251    ...               NaN            NaN         NaN           Marathi
# 18252    ...               NaN            NaN         NaN           Marathi
# 18253    ...               NaN            NaN         NaN             Hindi
# 18254    ...               NaN            NaN         NaN               NaN
#
#       LN2_WIndLngBEOth GN1_OTHERS GN2_OTHERS GN3_OTHERS GN4_OTHERS GN5_OTHERS
# 0                  NaN        NaN        NaN        NaN        NaN        NaN
# 1              Bengali        NaN        NaN        NaN        NaN        NaN
# 2                Hindi        NaN        NaN        NaN        NaN        NaN
# 3                Tamil        NaN        NaN        NaN        NaN        NaN
# 4            Malayalam        NaN        NaN        NaN        NaN        NaN
# 5          Chattisgari        NaN        NaN        NaN        NaN        NaN
# 6                  NaN        NaN        NaN        NaN        NaN        NaN
# 7               Telugu        NaN        NaN        NaN        NaN        NaN
# 8                  NaN        NaN        NaN        NaN        NaN        NaN
# 9              Marathi        NaN        NaN        NaN        NaN        NaN
# 10                 NaN        NaN        NaN        NaN        NaN        NaN
# 11               Hindi        NaN        NaN        NaN        NaN        NaN
# 12                 NaN        NaN        NaN        NaN        NaN        NaN
# 13               Hindi        NaN        NaN        NaN        NaN        NaN
# 14               Hindi        NaN        NaN        NaN        NaN        NaN
# 15          Rajasthani        NaN        NaN        NaN        NaN        NaN
# 16               Hindi        NaN        NaN        NaN        NaN        NaN
# 17                 NaN        NaN        NaN        NaN        NaN        NaN
# 18     Marathi & Hindi        NaN        NaN        NaN        NaN        NaN
# 19               Tamil        NaN        NaN        NaN        NaN        NaN
# 20                 NaN        NaN        NaN        NaN        NaN        NaN
# 21               Hindi        NaN        NaN        NaN        NaN        NaN
# 22                 NaN        NaN        NaN        NaN        NaN        NaN
# 23              Telugu        NaN        NaN        NaN        NaN        NaN
# 24            Assamese        NaN        NaN        NaN        NaN        NaN
# 25               Hindi        NaN        NaN        NaN        NaN        NaN
# 26                 NaN        NaN        NaN        NaN        NaN        NaN
# 27               Hindi        NaN        NaN        NaN        NaN        NaN
# 28                 NaN        NaN        NaN        NaN        NaN        NaN
# 29                 NaN        NaN        NaN        NaN        NaN        NaN
# ...                ...        ...        ...        ...        ...        ...
# 18225        Malayalam        NaN        NaN        NaN        NaN        NaN
# 18226            Tamil        NaN        NaN        NaN        NaN        NaN
# 18227        Malayalam        NaN        NaN        NaN        NaN        NaN
# 18228              NaN        NaN        NaN        NaN        NaN        NaN
# 18229              NaN        NaN        NaN        NaN        NaN        NaN
# 18230            Tamil        NaN        NaN        NaN        NaN        NaN
# 18231            Hindi        NaN        NaN        NaN        NaN        NaN
# 18232            Hindi        NaN        NaN        NaN        NaN        NaN
# 18233            Hindi        NaN        NaN        NaN        NaN        NaN
# 18234            Hindi        NaN        NaN        NaN        NaN        NaN
# 18235         Gujarati        NaN        NaN        NaN        NaN        NaN
# 18236          Bengali        NaN        NaN        NaN        NaN        NaN
# 18237            Hindi        NaN        NaN        NaN        NaN        NaN
# 18238         Gujarati        NaN        NaN        NaN        NaN        NaN
# 18239         Gujarati        NaN        NaN        NaN        NaN        NaN
# 18240          Bengali        NaN        NaN        NaN        NaN        NaN
# 18241        Malayalam        NaN        NaN        NaN        NaN        NaN
# 18242            Hindi        NaN        NaN        NaN        NaN        NaN
# 18243            Hindi        NaN        NaN        NaN        NaN        NaN
# 18244              NaN        NaN        NaN        NaN        NaN        NaN
# 18245            Hindi        NaN        NaN        NaN        NaN        NaN
# 18246          Bengali        NaN        NaN        NaN        NaN        NaN
# 18247            Hindi        NaN        NaN        NaN        NaN        NaN
# 18248          Bengali        NaN        NaN        NaN        NaN        NaN
# 18249            Oriya        NaN        NaN        NaN        NaN        NaN
# 18250              NaN        NaN        NaN        NaN        NaN        NaN
# 18251          Marathi        NaN        NaN        NaN        NaN        NaN
# 18252          Marathi        NaN        NaN        NaN        NaN        NaN
# 18253            Hindi        NaN        NaN        NaN        NaN        NaN
# 18254              NaN        NaN        NaN        NaN        NaN        NaN
#
# [18255 rows x 96 columns]

# %%
category_cols = df.select_dtypes(exclude=[np.number]).columns.tolist()
print(len(category_cols))
# Out:
# 96

# %% [markdown]
# ### convert categorical columns to integers
# * Our test set has categoricals not seen in train - this must be handled. For now, we'll get the categoricals from train and test together, ensuring we "see"/encode" all the categoricals

# %%
# Save # rows in train/test. (We could do this directly, but this is easier to debug if needed)
TR_ROWS = df.shape[0]
print(df.shape)
print(test.shape)
# Out:
# (18255, 1235)
# (27285, 1234)

# %%
df_all = pd.concat([df,test])
df_all.shape
# Out:
# (45540, 1236)

# %% [markdown]
# ## I get errors with LGB and other when using the Categorical datatype: we'll turn it back into Integers to avoid this

# %%
for header in category_cols:
#     df[header] = df[header].astype('category').cat.codes
#     test[header] = test[header].astype('category').cat.codes
    df_all[header] = df_all[header].astype('category').cat.codes.astype('int')
    df_all[header] = pd.to_numeric(df_all[header])
    
    df[header] = df[header].astype('category').cat.codes
    df[header] = pd.to_numeric(df[header])
    test[header] = test[header].astype('category').cat.codes
    test[header] = pd.to_numeric(test[header])

# %%
df.shape
# Out:
# (18255, 1235)

# %% [markdown]
# #### Split back into train and test

# %%
df =df_all.iloc[0:TR_ROWS]
test =df_all.iloc[TR_ROWS:]

df.drop(['test_id'],axis=1,inplace=True)
test.drop(['train_id',"is_female"],axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %% [markdown]
# ### Naive initial feature engineering:
# * NaNS per row
# (Could also be done for groups of columns, or to sum 0/1s.. (

# %%
df["row_nulls"] = df.isnull().sum(axis=1)
test["row_nulls"] = test.isnull().sum(axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Build a model
# * Note: CatBoost in particular has a LOT of hyperparams (it's even worse than LightGBM in this regard). IT's essential to experiment with them if you want to get decent results.
# * This is my first time using it, so assume my hyperparameters are terrible.
# * Tuning should use a seperate train/validation set split first to select hyperparams.
#
# * For low dimensional categoricals (e.g. <20 unique vars) - there's no benefit in embedding (Catboost/lightGBM) vs simply leaving it as a number or one hot encoding.

# %%
X = df.drop([TARGET],axis=1)# .select_dtypes(include=[np.number]) #.values
Y = df[TARGET]

# %%
### Optional Train/Validation split for test hyperparams. 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
from preprocess2 import *
X,test = preprocess(X, test)
# Out:
# C:\Users\cit-labs\Desktop\New folder\preprocess2.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test[header] = test[header].astype('category').cat.codes
# C:\Users\cit-labs\Desktop\New folder\preprocess2.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test[header] = pd.to_numeric(test[header])
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:3549: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
from sklearn.metrics import confusion_matrix
def classify(clf,x_n_train, y_n_train, x_n_test,y_n_test,test, useall = False):
    if useall:
        clf.fit(x_n_train, y_n_train)
#         test_n = test.reindex(columns = x_n_train.columns)
        test_n = test
    else:
        clf.fit(x_n_train, y_n_train)

        y_pred = clf.predict(x_n_test)

        cm = confusion_matrix(y_n_test, y_pred)
        print (cm)

        y_prob = clf.predict_proba(x_n_test)
        print(metrics.roc_auc_score(y_n_test, y_prob[:,1]))

        test_n = test.reindex(columns = x_n_test.columns)

    y_pred_f1 = clf.predict(test_n)
    y_prob = clf.predict_proba(test_n)
    return y_prob

# %%
cat_dims = [X.columns.get_loc(i) for i in category_cols[:-1]]  # categorical columns indexes

# train default catBoost classifier. Default loss metric is LogLoss (lower is better)
clf = CatBoostClassifier(eval_metric="AUC", one_hot_max_size=3, iterations=2)
from sklearn import metrics
# clf.fit(X,Y , cat_features=cat_dims)
classify(clf,X_train, y_train, X_test,y_test,test, useall = False)
# Out:
# 0:	learn: 0.9219430	total: 141ms	remaining: 141ms
# 1:	learn: 0.9272174	total: 235ms	remaining: 0us
# [[2132  416]
#  [ 350 2579]]
# 0.928431406179
# array([[ 0.45940806,  0.54059194],
#        [ 0.51654069,  0.48345931],
#        [ 0.45414245,  0.54585755],
#        ...,
#        [ 0.53469114,  0.46530886],
#        [ 0.48194774,  0.51805226],
#        [ 0.49402819,  0.50597181]])

# %% [markdown]
# ## Currently there's an error where when creating predictions - need to debug

# %%
res = clf.predict_proba(test)

# %%
res
# Out:
# array([[ 0.52319765,  0.47680235],
#        [ 0.55015584,  0.44984416],
#        [ 0.54251844,  0.45748156],
#        ...,
#        [ 0.54251844,  0.45748156],
#        [ 0.54251844,  0.45748156],
#        [ 0.55015584,  0.44984416]])

# %% [markdown]
# ## Additional models
# * Train performance is dangeorusly misleading without an external validation set.
# * This is just a starter for models
# * Should also check for overfitting (requires validation set split)

# %%
from selfea import *

# %%
# DataInit = InitData()

train = DataInit.get_train(False)
test = DataInit.get_test(False)

X_new = DataInit.get_train(True)
Y_new = DataInit.get_labels()
T_new = DataInit.get_test(True)
# T_new = T_new.reindex(columns = X_new)

# %%
len(test[])
# Out:
# 27285

# %%
train2, test2 = preprocess(train, test)

# %%
fea = DataInit.get_features()

# %%
train2[fea] = X_new

# %%
process_data(test)

# %%
test2[fea] = test[fea]

# %%
train2.columns
# Out:
# Index(['train_id', 'AA3', 'AA4', 'AA5', 'AA6', 'AA7', 'AA14', 'AA15', 'DG1',
#        'is_female',
#        ...
#        'MT1A_f', 'DL2_new', 'G2P1_11_new', 'GN2_new', 'FF14_6_new',
#        'FF14_5_new', 'FF14_4_new', 'FF14_3_new', 'MT18_5_new', 'MT18_4_new'],
#       dtype='object', length=1246)

# %%
len(test)
# Out:
# 27285

# %%
test2 = test[fea]

# %%
T_new
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     670                 type_pprinters=self.type_printers,
#     671                 deferred_pprinters=self.deferred_printers)
# --> 672             printer.pretty(obj)
#     673             printer.flush()
#     674             return stream.getvalue()
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __repr__(self)
#      70         Yields Bytestring in Py2, Unicode String in py3.
#      71         """
# ---> 72         return str(self)
#      73
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __str__(self)
#      49
#      50         if compat.PY3:
# ---> 51             return self.__unicode__()
#      52         return self.__bytes__()
#      53
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __unicode__(self)
#     584             width = None
#     585         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 586                        line_width=width, show_dimensions=show_dimensions)
#     587
#     588         return buf.getvalue()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1537                                            max_cols=max_cols,
#    1538                                            show_dimensions=show_dimensions)
# -> 1539         formatter.to_string()
#    1540
#    1541         if buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     581         else:
#     582
# --> 583             strcols = self._to_str_columns()
#     584             if self.line_width is None:  # no need to wrap around just print
#     585                 # the whole frame
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _to_str_columns(self)
#     509                 str_columns = [[label] for label in self.header]
#     510             else:
# --> 511                 str_columns = self._get_formatted_column_labels(frame)
#     512
#     513             stringified = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_column_labels(self, frame)
#     753             str_columns = [list(x) for x in zip(*str_columns)]
#     754         else:
# --> 755             fmt_columns = columns.format()
#     756             dtypes = self.frame.dtypes
#     757             need_leadsp = dict(zip(fmt_columns, map(is_numeric_dtype, dtypes)))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in format(self, name, formatter, **kwargs)
#    1845             return header + list(self.map(formatter))
#    1846
# -> 1847         return self._format_with_header(header, **kwargs)
#    1848
#    1849     def _format_with_header(self, header, na_rep='NaN', **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _format_with_header(self, header, na_rep, **kwargs)
#    1869
#    1870         else:
# -> 1871             result = _trim_front(format_array(values, None, justify='left'))
#    1872         return header + result
#    1873
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1750                         space=space, justify=justify, decimal=decimal)
#    1751
# -> 1752     return fmt_obj.get_result()
#    1753
#    1754
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1770
#    1771     def get_result(self):
# -> 1772         fmt_values = self._format_strings()
#    1773         return _make_fixed_width(fmt_values, self.justify)
#    1774
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1952             return [self.formatter(x) for x in self.values]
#    1953
# -> 1954         return list(self.get_result_as_array())
#    1955
#    1956
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result_as_array(self)
#    1917             float_format = self.float_format
#    1918
# -> 1919         formatted_values = format_values_with(float_format)
#    1920
#    1921         if not self.fixed_width:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in format_values_with(float_format)
#    1906
#    1907             if self.fixed_width:
# -> 1908                 return _trim_zeros(values, self.na_rep)
#    1909
#    1910             return values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _trim_zeros(str_floats, na_rep)
#    2255                 not (any([('e' in x) or ('E' in x) for x in non_na])))
#    2256
# -> 2257     while _cond(trimmed):
#    2258         trimmed = [x[:-1] if x != na_rep else x for x in trimmed]
#    2259
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _cond(values)
#    2251
#    2252     def _cond(values):
# -> 2253         non_na = [x for x in values if x != na_rep]
#    2254         return (len(non_na) > 0 and all([x.endswith('0') for x in non_na]) and
#    2255                 not (any([('e' in x) or ('E' in x) for x in non_na])))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in <listcomp>(.0)
#    2251
#    2252     def _cond(values):
# -> 2253         non_na = [x for x in values if x != na_rep]
#    2254         return (len(non_na) > 0 and all([x.endswith('0') for x in non_na]) and
#    2255                 not (any([('e' in x) or ('E' in x) for x in non_na])))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     617
#     618             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 619                                 show_dimensions=show_dimensions, notebook=True)
#     620         else:
#     621             return None
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border)
#    1592                                            decimal=decimal)
#    1593         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 1594         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    1595
#    1596         if buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     718                                       border=border)
#     719         if hasattr(self.buf, 'write'):
# --> 720             html_renderer.write_result(self.buf)
#     721         elif isinstance(self.buf, compat.string_types):
#     722             with open(self.buf, 'w') as f:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in write_result(self, buf)
#    1157         indent += self.indent_delta
#    1158         indent = self._write_header(indent)
# -> 1159         indent = self._write_body(indent)
#    1160
#    1161         self.write('</table>', indent)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _write_body(self, indent)
#    1309         fmt_values = {}
#    1310         for i in range(min(len(self.columns), self.max_cols)):
# -> 1311             fmt_values[i] = self.fmt._format_col(i)
#    1312
#    1313         # write values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     690     def _format_col(self, i):
#     691         frame = self.tr_frame
# --> 692         formatter = self._get_formatter(i)
#     693         return format_array(frame.iloc[:, i]._values, formatter,
#     694                             float_format=self.float_format, na_rep=self.na_rep,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatter(self, i)
#     347             if is_integer(i) and i not in self.columns:
#     348                 i = self.columns[i]
# --> 349             return self.formatters.get(i, None)
#     350
#     351
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
# 
ytrain = train2.is_female
xtrain = train2.drop(["is_female"],axis = 1)
# train.is_female

# %%
# increase # iterations when model debugged
clf2 = CatBoostClassifier(eval_metric="AUC", one_hot_max_size=6,
                          iterations=50,depth=8,learning_rate=0.04, rsm=0.8)

# clf2.fit(xtrain,ytrain)
# res2 = clf2.predict_proba(test2)
# classify(clf2,X_train, y_train, X_test,y_test,test, useall = False)
res5 = classify(clf2,train2.drop([TARGET],axis=1).values,train2.is_female, None,None,test2,True)
# Out:
# 0:	learn: 0.9172374	total: 164ms	remaining: 8.04s
# 1:	learn: 0.9414040	total: 326ms	remaining: 7.83s
# 2:	learn: 0.9441676	total: 497ms	remaining: 7.79s
# 3:	learn: 0.9458347	total: 660ms	remaining: 7.59s
# 4:	learn: 0.9454476	total: 828ms	remaining: 7.45s
# 5:	learn: 0.9498443	total: 994ms	remaining: 7.29s
# 6:	learn: 0.9499815	total: 1.17s	remaining: 7.17s
# 7:	learn: 0.9507401	total: 1.34s	remaining: 7.03s
# 8:	learn: 0.9515597	total: 1.52s	remaining: 6.92s
# 9:	learn: 0.9512022	total: 1.68s	remaining: 6.72s
# 10:	learn: 0.9528523	total: 1.85s	remaining: 6.58s
# 11:	learn: 0.9549246	total: 2.02s	remaining: 6.38s
# 12:	learn: 0.9558251	total: 2.18s	remaining: 6.2s
# 13:	learn: 0.9561767	total: 2.33s	remaining: 6s
# 14:	learn: 0.9561315	total: 2.48s	remaining: 5.78s
# 15:	learn: 0.9563126	total: 2.64s	remaining: 5.61s
# 16:	learn: 0.9569005	total: 2.81s	remaining: 5.45s
# 17:	learn: 0.9571982	total: 2.97s	remaining: 5.28s
# 18:	learn: 0.9577399	total: 3.13s	remaining: 5.11s
# 19:	learn: 0.9586100	total: 3.31s	remaining: 4.96s
# 20:	learn: 0.9586053	total: 3.49s	remaining: 4.82s
# 21:	learn: 0.9590834	total: 3.64s	remaining: 4.63s
# 22:	learn: 0.9588723	total: 3.81s	remaining: 4.48s
# 23:	learn: 0.9592764	total: 3.97s	remaining: 4.3s
# 24:	learn: 0.9594326	total: 4.14s	remaining: 4.14s
# 25:	learn: 0.9596371	total: 4.31s	remaining: 3.98s
# 26:	learn: 0.9601370	total: 4.48s	remaining: 3.82s
# 27:	learn: 0.9604681	total: 4.64s	remaining: 3.65s
# 28:	learn: 0.9608562	total: 4.82s	remaining: 3.49s
# 29:	learn: 0.9612679	total: 4.97s	remaining: 3.32s
# 30:	learn: 0.9619650	total: 5.15s	remaining: 3.15s
# 31:	learn: 0.9621773	total: 5.3s	remaining: 2.98s
# 32:	learn: 0.9622945	total: 5.47s	remaining: 2.82s
# 33:	learn: 0.9627156	total: 5.63s	remaining: 2.65s
# 34:	learn: 0.9630756	total: 5.79s	remaining: 2.48s
# 35:	learn: 0.9632033	total: 5.95s	remaining: 2.31s
# 36:	learn: 0.9632925	total: 6.13s	remaining: 2.15s
# 37:	learn: 0.9635181	total: 6.3s	remaining: 1.99s
# 38:	learn: 0.9638515	total: 6.48s	remaining: 1.83s
# 39:	learn: 0.9640244	total: 6.64s	remaining: 1.66s
# 40:	learn: 0.9642467	total: 6.81s	remaining: 1.49s
# 41:	learn: 0.9644116	total: 6.96s	remaining: 1.32s
# 42:	learn: 0.9647381	total: 7.13s	remaining: 1.16s
# 43:	learn: 0.9648782	total: 7.29s	remaining: 994ms
# 44:	learn: 0.9651299	total: 7.46s	remaining: 829ms
# 45:	learn: 0.9653674	total: 7.63s	remaining: 663ms
# 46:	learn: 0.9655714	total: 7.79s	remaining: 497ms
# 47:	learn: 0.9657073	total: 7.95s	remaining: 331ms
# 48:	learn: 0.9658555	total: 8.12s	remaining: 166ms
# 49:	learn: 0.9659796	total: 8.28s	remaining: 0us

# %%
res5
# Out:
# array([[ 0.62021403,  0.37978597],
#        [ 0.57584973,  0.42415027],
#        [ 0.67222974,  0.32777026],
#        ...,
#        [ 0.52816241,  0.47183759],
#        [ 0.60896794,  0.39103206],
#        [ 0.67664623,  0.32335377]])

# %%
write_file("sub2.csv",res5)

# %% [markdown]
# ## Simple LightGBM model:
# * https://github.com/Microsoft/LightGBM/issues/1096

# %%
# we still ahve object datatypes columns..
df.dtypes.value_counts()
# Out:
# float64    910
# int64      240
# object      96
# dtype: int64

# %%
# categorical/objects cols:
print(df.select_dtypes(exclude=[np.number]).columns.tolist())
# df.select_dtypes(exclude=[np.number]).value_counts()
# Out:
# ['DG4_OTHERS', 'FB28_3_OTHERS', 'G2P2_10_OTHERS', 'G2P2_12_OTHERS', 'G2P2_15_OTHERS', 'G2P2_2_OTHERS', 'MM11_11_OTHERS', 'MM11_5_OTHERS', 'MM15_OTHERS', 'MM38_OTHERS', 'MT13_4_OTHERS', 'MT13_96_OTHERS', 'MT14_3_OTHERS', 'MT14_5_OTHERS', 'MT14_7_OTHERS']

# %%
# lgb_train = lgb.Dataset(
# #             data=LabelEncoder().fit_transform(train_df.brand_name).reshape(-1, 1),
#     data=df.drop([TARGET],axis=1).select_dtypes(include=[np.number]).values,
#     label = df[TARGET],
# #     categorical_feature=cat_dims   
#         )

lgb_train = lgb.Dataset(
#             data=LabelEncoder().fit_transform(train_df.brand_name).reshape(-1, 1),
    data=train2.drop([TARGET],axis=1).values,
    label = train2[TARGET],
#     categorical_feature=cat_dims   
        )

# %%
# https://github.com/Microsoft/LightGBM/blob/master/docs/Parameters.rst
t4_params = {
    'boosting_type': 'gbdt', 'objective': 'binary', 'nthread': -1, 'silent': False,
    'num_leaves': 2**4, 'learning_rate': 0.05, 'max_depth': 11,
    'max_bin': 255, 
    'subsample': 0.8, 'subsample_freq': 1, 'colsample_bytree': 0.75, 
#     'early_stopping_round' : 10,
    'min_split_gain': 0.5, 'min_child_samples': 4}

clf_lgb = lgb.train(t4_params,lgb_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:657: UserWarning: silent keyword has been found in `params` and will be ignored. Please use silent argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))

# %%
res_lgbm = clf_lgb.predict(test2)

# %%
len(res_lgbm)
# Out:
# 27285

# %%
res_lgbm
# Out:
# array([ 0.40402583,  0.67728182,  0.45158917, ...,  0.7333295 ,
#         0.19231664,  0.46090632])

# %%
write_file("sub3.csv",res_lgbm)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-d47e9d901195> in <module>()
# ----> 1 write_file("sub3.csv",res_lgbm)
#
# C:\Users\cit-labs\Desktop\New folder\selfea.py in write_file(fname, y_prob)
#     204         wri.writeheader()
#     205         for i in y_prob:
# --> 206             wri.writerow({"test_id":acc, "is_female": i[1]})
#     207             acc = acc+1
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# #### Once more predictions work, can join and get mean of predictions = simple blending ensemble

# %%
# test["lgbm_preds"]=res_lgbm
test["is_female"]=res_lgbm

# %%
print(res2[:,1])
# Out:
# [ 0.62025603  0.61955426  0.53572687 ...,  0.52719749  0.51435788
#   0.52155349]

# %%
print(res_lgbm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8962eb250bb5> in <module>()
# ----> 1 print(res_lgbm)
#
# NameError: name 'res_lgbm' is not defined

# %%
test["is_female"] = res5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'is_female'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in set(self, item, value, check)
#    3714         try:
# -> 3715             loc = self.items.get_loc(item)
#    3716         except KeyError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'is_female'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-31134d2d35c2> in <module>()
# ----> 1 test["is_female"] = res5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2494         self._ensure_valid_index(value)
#    2495         value = self._sanitize_column(key, value)
# -> 2496         NDFrame._set_item(self, key, value)
#    2497
#    2498         # check if we are modifying a copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    1646
#    1647     def _set_item(self, key, value):
# -> 1648         self._data.set(key, value)
#    1649         self._clear_item_cache()
#    1650
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in set(self, item, value, check)
#    3716         except KeyError:
#    3717             # This item wasn't present, just insert at end
# -> 3718             self.insert(len(self.items), item, value)
#    3719             return
#    3720
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    3817
#    3818         block = make_block(values=value, ndim=self.ndim,
# -> 3819                            placement=slice(loc, loc + 1))
#    3820
#    3821         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    2717                      placement=placement, dtype=dtype)
#    2718
# -> 2719     return klass(values, ndim=ndim, fastpath=fastpath, placement=placement)
#    2720
#    2721 # TODO: flexible with index=None and/or items=None
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim, fastpath)
#     113             raise ValueError('Wrong number of items passed %d, placement '
#     114                              'implies %d' % (len(self.values),
# --> 115                                              len(self.mgr_locs)))
#     116
#     117     @property
#
# ValueError: Wrong number of items passed 2, placement implies 1

# %%
test["test_id"] = test["test_id"].astype(int)

# %%
test[["test_id","is_female"]].to_csv("submission6.csv",index=False)

# %%
# preds = pd.DataFrame(columns=[test["test_id"].copy(),res_lgbm]
# preds = test["test_id"].copy()
# preds["is_female"] = res_lgbm# ensemble/mean of others at this points

# %%
# preds.head()

# %%
# preds.to_csv("submission.csv.gz",index=False,compression="gzip")
